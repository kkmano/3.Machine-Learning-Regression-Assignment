# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
'max_features': [1.0,'sqrt','log2'],
'splitter':['best','random']}

# %%
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-3)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-3,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [1.0, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
re
# Out:
# {'mean_fit_time': array([0.00952578, 0.01043472, 0.01115117, 0.00921922, 0.01043768,
#         0.00666089, 0.00729856, 0.00946083, 0.00896597, 0.00857525,
#         0.01012425, 0.00817289, 0.04749551, 0.03730984, 0.02658906,
#         0.0232769 , 0.03215942, 0.02386045, 0.01374149, 0.00781751,
#         0.00697856, 0.00761957, 0.01095161, 0.00743184]),
#  'std_fit_time': array([0.00487042, 0.00101672, 0.00494314, 0.00155542, 0.00452226,
#         0.00227731, 0.00062813, 0.00222291, 0.00365834, 0.00249553,
#         0.00323734, 0.00328944, 0.00660576, 0.00390464, 0.00171769,
#         0.00692234, 0.00376819, 0.00489227, 0.00697755, 0.0015788 ,
#         0.00075732, 0.0010628 , 0.00306006, 0.00256792]),
#  'mean_score_time': array([0.00327024, 0.00362358, 0.00848503, 0.0078896 , 0.00807915,
#         0.0034153 , 0.00538549, 0.00421829, 0.00416989, 0.00420084,
#         0.00581236, 0.003898  , 0.00383673, 0.00440722, 0.00406747,
#         0.00320239, 0.0036912 , 0.00524397, 0.00555677, 0.00511441,
#         0.00308342, 0.00681839, 0.006183  , 0.00452604]),
#  'std_score_time': array([2.12919549e-03, 2.05963174e-03, 4.16848314e-03, 7.03885548e-03,
#         6.36218891e-03, 2.65448847e-03, 1.39752777e-03, 2.90318290e-03,
#         1.15295028e-03, 6.96859432e-04, 2.75696971e-03, 6.40598212e-04,
#         9.08987454e-04, 8.04863246e-04, 7.54854403e-04, 4.76874765e-04,
#         1.00079485e-03, 1.14760654e-03, 1.05169465e-03, 1.02536317e-03,
#         1.72509641e-05, 1.90995651e-03, 2.61082955e-03, 1.41851313e-03]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                     'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[1.0, 1.0, 'sqrt', 'sqrt', 'log2', 'log2', 1.0, 1.0,
#                     'sqrt', 'sqrt', 'log2', 'log2', 1.0, 1.0, 'sqrt',
#                     'sqrt', 'log2', 'log2', 1.0, 1.0, 'sqrt', 'sqrt',
#                     'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_splitter': masked_array(data=['best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'squared_error',
#    'max_features': 1.0,
#    'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 1.0, 'splitter': 'random'},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 1.0, 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 1.0, 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 1.0, 'splitter': 'best'},
#   {'criterion': 'absolute_error', 'max_features': 1.0, 'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'sqrt',
#    'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'log2',
#    'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 1.0, 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 1.0, 'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'random'}],
#  'split0_test_score': array([0.74206898, 0.71133563, 0.77380169, 0.71851717, 0.64624877,
#         0.73852717, 0.75453384, 0.69565084, 0.60967202, 0.53594261,
#         0.7349038 , 0.64783437, 0.74535562, 0.66622886, 0.81975132,
#         0.53779491, 0.61711247, 0.58448294, 0.69551372, 0.63215664,
#         0.7669896 , 0.63935262, 0.7338    , 0.61310952]),
#  'split1_test_score': array([0.55104461, 0.62382908, 0.63687481, 0.5626164 , 0.47012513,
#         0.5162992 , 0.53782903, 0.54934488, 0.6894112 , 0.62777931,
#         0.62135829, 0.57340528, 0.63528808, 0.58687399, 0.62077898,
#         0.61002211, 0.60174508, 0.5200562 , 0.63184294, 0.67211842,
#         0.69355327, 0.64428884, 0.60469623, 0.64978493]),
#  'split2_test_score': array([0.76662282, 0.6144806 , 0.70878894, 0.62894456, 0.65247569,
#         0.59673925, 0.76470544, 0.71825358, 0.65622721, 0.36913652,
#         0.64705109, 0.36142288, 0.61664581, 0.66858486, 0.63273317,
#         0.72442383, 0.7084733 , 0.65367822, 0.68402788, 0.65514102,
#         0.69845732, 0.59183949, 0.59525801, 0.64757947]),
#  'split3_test_score': array([0.64546678, 0.58750107, 0.67378644, 0.62474198, 0.68597387,
#         0.50680485, 0.60237776, 0.54253479, 0.57885748, 0.61111213,
#         0.6306843 , 0.34877586, 0.56469649, 0.67438176, 0.55164764,
#         0.53218267, 0.62308067, 0.73462559, 0.56742029, 0.5817999 ,
#         0.63721935, 0.61755439, 0.58486024, 0.59814865]),
#  'split4_test_score': array([0.65254498, 0.65950262, 0.60703514, 0.5774359 , 0.61893946,
#         0.61783988, 0.65973351, 0.6363116 , 0.57556627, 0.63636492,
#         0.52269426, 0.49605881, 0.6500599 , 0.66944342, 0.60699349,
#         0.24362483, 0.66411202, 0.65590473, 0.62411219, 0.65208938,
#         0.4091068 , 0.54348423, 0.62459881, 0.58544289]),
#  'mean_test_score': array([0.67154964, 0.6393298 , 0.6800574 , 0.6224512 , 0.61475258,
#         0.59524207, 0.66383592, 0.62841914, 0.62194684, 0.5560671 ,
#         0.63133835, 0.48549944, 0.64240918, 0.65310258, 0.64638092,
#         0.52960967, 0.64290471, 0.62974954, 0.6405834 , 0.63866107,
#         0.64106527, 0.60730391, 0.62864266, 0.61881309]),
#  'std_test_score': array([0.07690883, 0.04274519, 0.05805136, 0.05455761, 0.07539515,
#         0.08378143, 0.08726104, 0.07250032, 0.04446371, 0.09996837,
#         0.06764061, 0.1168588 , 0.05900886, 0.03322064, 0.09102174,
#         0.15892115, 0.03873329, 0.07257735, 0.04605496, 0.03113456,
#         0.12306526, 0.03691118, 0.05418355, 0.0259225 ]),
#  'rank_test_score': array([ 2, 10,  1, 16, 19, 21,  3, 15, 17, 22, 12, 24,  7,  4,  5, 23,  6,
#         13,  9, 11,  8, 20, 14, 18])}

# %%
y_pred=grid.predict(X_test)

# %%
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009526      0.004870         0.003270        0.002129
# 1        0.010435      0.001017         0.003624        0.002060
# 2        0.011151      0.004943         0.008485        0.004168
# 3        0.009219      0.001555         0.007890        0.007039
# 4        0.010438      0.004522         0.008079        0.006362
# 5        0.006661      0.002277         0.003415        0.002654
# 6        0.007299      0.000628         0.005385        0.001398
# 7        0.009461      0.002223         0.004218        0.002903
# 8        0.008966      0.003658         0.004170        0.001153
# 9        0.008575      0.002496         0.004201        0.000697
# 10       0.010124      0.003237         0.005812        0.002757
# 11       0.008173      0.003289         0.003898        0.000641
# 12       0.047496      0.006606         0.003837        0.000909
# 13       0.037310      0.003905         0.004407        0.000805
# 14       0.026589      0.001718         0.004067        0.000755
# 15       0.023277      0.006922         0.003202        0.000477
# 16       0.032159      0.003768         0.003691        0.001001
# 17       0.023860      0.004892         0.005244        0.001148
# 18       0.013741      0.006978         0.005557        0.001052
# 19       0.007818      0.001579         0.005114        0.001025
# 20       0.006979      0.000757         0.003083        0.000017
# 21       0.007620      0.001063         0.006818        0.001910
# 22       0.010952      0.003060         0.006183        0.002611
# 23       0.007432      0.002568         0.004526        0.001419
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error                1.0           best
# 1    squared_error                1.0         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse                1.0           best
# 7     friedman_mse                1.0         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error                1.0           best
# 13  absolute_error                1.0         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson                1.0           best
# 19         poisson                1.0         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.742069
# 1   {'criterion': 'squared_error', 'max_features':...           0.711336
# 2   {'criterion': 'squared_error', 'max_features':...           0.773802
# 3   {'criterion': 'squared_error', 'max_features':...           0.718517
# 4   {'criterion': 'squared_error', 'max_features':...           0.646249
# 5   {'criterion': 'squared_error', 'max_features':...           0.738527
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.754534
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.695651
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.609672
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.535943
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.734904
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.647834
# 12  {'criterion': 'absolute_error', 'max_features'...           0.745356
# 13  {'criterion': 'absolute_error', 'max_features'...           0.666229
# 14  {'criterion': 'absolute_error', 'max_features'...           0.819751
# 15  {'criterion': 'absolute_error', 'max_features'...           0.537795
# 16  {'criterion': 'absolute_error', 'max_features'...           0.617112
# 17  {'criterion': 'absolute_error', 'max_features'...           0.584483
# 18  {'criterion': 'poisson', 'max_features': 1.0, ...           0.695514
# 19  {'criterion': 'poisson', 'max_features': 1.0, ...           0.632157
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.766990
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.639353
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.733800
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.613110
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.551045           0.766623           0.645467
# 1            0.623829           0.614481           0.587501
# 2            0.636875           0.708789           0.673786
# 3            0.562616           0.628945           0.624742
# 4            0.470125           0.652476           0.685974
# 5            0.516299           0.596739           0.506805
# 6            0.537829           0.764705           0.602378
# 7            0.549345           0.718254           0.542535
# 8            0.689411           0.656227           0.578857
# 9            0.627779           0.369137           0.611112
# 10           0.621358           0.647051           0.630684
# 11           0.573405           0.361423           0.348776
# 12           0.635288           0.616646           0.564696
# 13           0.586874           0.668585           0.674382
# 14           0.620779           0.632733           0.551648
# 15           0.610022           0.724424           0.532183
# 16           0.601745           0.708473           0.623081
# 17           0.520056           0.653678           0.734626
# 18           0.631843           0.684028           0.567420
# 19           0.672118           0.655141           0.581800
# 20           0.693553           0.698457           0.637219
# 21           0.644289           0.591839           0.617554
# 22           0.604696           0.595258           0.584860
# 23           0.649785           0.647579           0.598149
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.652545         0.671550        0.076909                2
# 1            0.659503         0.639330        0.042745               10
# 2            0.607035         0.680057        0.058051                1
# 3            0.577436         0.622451        0.054558               16
# 4            0.618939         0.614753        0.075395               19
# 5            0.617840         0.595242        0.083781               21
# 6            0.659734         0.663836        0.087261                3
# 7            0.636312         0.628419        0.072500               15
# 8            0.575566         0.621947        0.044464               17
# 9            0.636365         0.556067        0.099968               22
# 10           0.522694         0.631338        0.067641               12
# 11           0.496059         0.485499        0.116859               24
# 12           0.650060         0.642409        0.059009                7
# 13           0.669443         0.653103        0.033221                4
# 14           0.606993         0.646381        0.091022                5
# 15           0.243625         0.529610        0.158921               23
# 16           0.664112         0.642905        0.038733                6
# 17           0.655905         0.629750        0.072577               13
# 18           0.624112         0.640583        0.046055                9
# 19           0.652089         0.638661        0.031135               11
# 20           0.409107         0.641065        0.123065                8
# 21           0.543484         0.607304        0.036911               20
# 22           0.624599         0.628643        0.054184               14
# 23           0.585443         0.618813        0.025922               18

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 29
# BMI: 26.5
# Children: 0
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[48549.17835]

# %%
import pickle

# %%
filename='final_model_DC.sav'

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('final_model_DC.sav','rb'))

# %%
result=loaded_model.predict([[29,26.5,0,1,1]])

# %%
result
# Out:
# array([49577.6624])

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.750444808336148
