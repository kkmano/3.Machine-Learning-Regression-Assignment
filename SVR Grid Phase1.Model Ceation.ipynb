# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.53963418,  0.11036616, -0.90788827, -0.98885138, -0.49929923],
#        [ 0.74809711,  0.26412451, -0.0755796 ,  1.01127431,  2.00280702],
#        [ 0.4621307 ,  2.13997636,  1.58903774,  1.01127431, -0.49929923],
#        ...,
#        [ 0.03318108, -0.90443894, -0.90788827,  1.01127431, -0.49929923],
#        [-1.46814257,  0.7869029 , -0.90788827,  1.01127431, -0.49929923],
#        [-0.46726014, -1.96941782, -0.0755796 , -0.98885138, -0.49929923]])

# %%
X_test
# Out:
# array([[ 0.89108031, -0.07576237, -0.0755796 ,  1.01127431, -0.49929923],
#        [ 0.5336223 , -0.21009861, -0.0755796 , -0.98885138, -0.49929923],
#        [ 0.6051139 ,  1.60182214,  0.75672907,  1.01127431,  2.00280702],
#        ...,
#        [-1.46814257,  0.65256665,  0.75672907, -0.98885138,  2.00280702],
#        [-0.82471815,  0.37742013,  1.58903774,  1.01127431, -0.49929923],
#        [ 0.89108031,  1.24817794,  0.75672907, -0.98885138, -0.49929923]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid={'kernel':['linear', 'poly', 'rbf', 'sigmoid'],'C':[100,1000,2000,3000],'gamma':['scale', 'auto']}

grid=GridSearchCV(SVR(),param_grid, refit=True, verbose=3, n_jobs=-1)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [100, 1000, 2000, 3000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}:

# %%
 table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.058382      0.003801         0.009522        0.001779     100
# 1        0.056900      0.009019         0.009007        0.003711     100
# 2        0.058336      0.005363         0.032137        0.003855     100
# 3        0.068971      0.002572         0.010301        0.005812     100
# 4        0.053833      0.006300         0.008844        0.002583     100
# 5        0.049027      0.004387         0.011023        0.000945     100
# 6        0.052270      0.005006         0.036958        0.002672     100
# 7        0.065094      0.002454         0.017823        0.004199     100
# 8        0.069947      0.003708         0.006732        0.004648    1000
# 9        0.071203      0.008597         0.011192        0.003524    1000
# 10       0.077644      0.005785         0.033876        0.003631    1000
# 11       0.065207      0.003976         0.016097        0.003701    1000
# 12       0.068780      0.007322         0.008814        0.007251    1000
# 13       0.077093      0.008422         0.006924        0.004456    1000
# 14       0.074292      0.005343         0.033167        0.004598    1000
# 15       0.073181      0.008795         0.014444        0.003080    1000
# 16       0.090585      0.008938         0.005210        0.002980    2000
# 17       0.191106      0.164555         0.010078        0.001417    2000
# 18       0.085100      0.002735         0.029324        0.004800    2000
# 19       0.077645      0.005425         0.010795        0.002426    2000
# 20       0.088808      0.006819         0.010467        0.002275    2000
# 21       0.157341      0.059092         0.008095        0.004868    2000
# 22       0.087369      0.010239         0.039199        0.009717    2000
# 23       0.084000      0.006772         0.015508        0.005196    2000
# 24       0.106851      0.017369         0.008891        0.004591    3000
# 25       0.183543      0.051058         0.010186        0.003227    3000
# 26       0.098404      0.008279         0.036549        0.005862    3000
# 27       0.088613      0.007313         0.014143        0.002055    3000
# 28       0.110607      0.019146         0.010215        0.002163    3000
# 29       0.263332      0.148226         0.004437        0.004096    3000
# 30       0.096880      0.006569         0.031982        0.001895    3000
# 31       0.079729      0.007956         0.014088        0.003959    3000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale         poly
# 2        scale          rbf
# 3        scale      sigmoid
# 4         auto       linear
# 5         auto         poly
# 6         auto          rbf
# 7         auto      sigmoid
# 8        scale       linear
# 9        scale         poly
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto         poly
# 14        auto          rbf
# 15        auto      sigmoid
# 16       scale       linear
# 17       scale         poly
# 18       scale          rbf
# 19       scale      sigmoid
# 20        auto       linear
# 21        auto         poly
# 22        auto          rbf
# 23        auto      sigmoid
# 24       scale       linear
# 25       scale         poly
# 26       scale          rbf
# 27       scale      sigmoid
# 28        auto       linear
# 29        auto         poly
# 30        auto          rbf
# 31        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.596232
# 1      {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.532310
# 2       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.304939
# 3   {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.491855
# 4     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.596232
# 5       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.542212
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.303414
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.492088
# 8   {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.686126
# 9     {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.798212
# 10     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.732079
# 11  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.248266
# 12   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.686126
# 13     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.799185
# 14      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.731430
# 15  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.232428
# 16  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.669958
# 17    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.804708
# 18     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.789144
# 19  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.370980
# 20   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.669958
# 21     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.804603
# 22      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.788746
# 23  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.656854
# 24  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.669819
# 25    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.805169
# 26     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.795353
# 27  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.651895
# 28   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.669819
# 29     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.804915
# 30      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.795104
# 31  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.795299
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.635776           0.566816           0.588799
# 1            0.571466           0.474948           0.537506
# 2            0.318480           0.155033           0.208422
# 3            0.544604           0.439299           0.468556
# 4            0.635776           0.566816           0.588799
# 5            0.566743           0.471172           0.537557
# 6            0.319385           0.155546           0.208414
# 7            0.545107           0.438714           0.468576
# 8            0.598398           0.586104           0.573860
# 9            0.787019           0.823118           0.810712
# 10           0.715992           0.686057           0.710177
# 11           0.377692           0.315321           0.291779
# 12           0.598398           0.586104           0.573860
# 13           0.786769           0.821307           0.810704
# 14           0.716349           0.686476           0.710172
# 15           0.306815           0.236688           0.291707
# 16           0.592446           0.586953           0.572862
# 17           0.784713           0.847781           0.807295
# 18           0.764022           0.818319           0.794133
# 19          -0.421011          -0.350248          -0.483750
# 20           0.592446           0.586953           0.572862
# 21           0.784782           0.847674           0.807280
# 22           0.764261           0.818616           0.794131
# 23          -0.432695          -0.346330          -0.484052
# 24           0.588893           0.587076           0.572849
# 25           0.783163           0.852345           0.810160
# 26           0.772801           0.846034           0.811601
# 27          -2.010670          -1.468842          -1.712109
# 28           0.588893           0.587076           0.572849
# 29           0.783304           0.852190           0.810160
# 30           0.772917           0.846181           0.811601
# 31          -1.629662          -1.461919          -1.712710
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.537415         0.585008        0.032600               19
# 1            0.415264         0.506299        0.055077               21
# 2            0.161488         0.229672        0.069604               28
# 3            0.424226         0.473708        0.042461               24
# 4            0.537415         0.585008        0.032600               19
# 5            0.413719         0.506281        0.056081               22
# 6            0.161756         0.229703        0.069348               27
# 7            0.425516         0.474000        0.042447               23
# 8            0.556109         0.600119        0.045217               13
# 9            0.719979         0.787808        0.036003                7
# 10           0.613122         0.691485        0.041876               12
# 11           0.346175         0.315846        0.044478               25
# 12           0.556109         0.600119        0.045217               13
# 13           0.719528         0.787499        0.035885                8
# 14           0.613293         0.691544        0.041718               11
# 15           0.346868         0.282901        0.043415               26
# 16           0.556109         0.595666        0.039218               15
# 17           0.745732         0.798046        0.033220                3
# 18           0.709586         0.775041        0.036992               10
# 19          -0.087414        -0.342681        0.135687               29
# 20           0.556109         0.595666        0.039218               15
# 21           0.745448         0.797957        0.033268                4
# 22           0.709676         0.775086        0.036986                9
# 23          -0.076409        -0.399268        0.190629               30
# 24           0.557014         0.595130        0.039068               17
# 25           0.748201         0.799808        0.034165                1
# 26           0.725615         0.790281        0.040189                6
# 27          -0.961821        -1.561068        0.346643               32
# 28           0.557014         0.595130        0.039068               17
# 29           0.748175         0.799749        0.034104                2
# 30           0.725697         0.790300        0.040188                5
# 31          -0.929359        -1.505790        0.308601               31

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 29
# BMI: 26
# Children: 0
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

# %%
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[3616454.72643123]

# %%
import pickle

# %%
filename='Final_model_svr.sav'

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('Final_model_svr.sav','rb'))

# %%
result=loaded_model.predict([[29,26,0,1,1]])

# %%
result
# Out:
# array([3616454.72643123])
