# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid={'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],'max_features':['sqrt', 'log2'], 'n_estimators':[10,100,100]}

# %%
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid=grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
re=grid.cv_results_

# %%
re
# Out:
# {'mean_fit_time': array([0.07124519, 0.45372572, 0.44322991, 0.05616813, 0.43446221,
#         0.43200989, 0.12965822, 1.22602153, 1.53703785, 0.14652224,
#         2.37213802, 2.57459006, 0.13270311, 0.92287321, 0.94118543,
#         0.11850219, 0.93661938, 0.93845401, 0.11570363, 1.03132787,
#         1.07667861, 0.11529446, 1.06544795, 0.89233465]),
#  'std_fit_time': array([0.00340466, 0.0150965 , 0.00823301, 0.00636731, 0.01357724,
#         0.00776532, 0.00788516, 0.0275438 , 0.37685417, 0.01233925,
#         0.12327721, 0.22773165, 0.02172541, 0.01222321, 0.00863436,
#         0.01085863, 0.01857805, 0.01261109, 0.00300749, 0.01835067,
#         0.04436957, 0.00873187, 0.02641134, 0.06119945]),
#  'mean_score_time': array([0.00753675, 0.01446176, 0.01559324, 0.00498919, 0.02057557,
#         0.01444254, 0.0038847 , 0.01775794, 0.02258306, 0.00372906,
#         0.03631577, 0.0354547 , 0.01180129, 0.03781972, 0.03663516,
# ...

# %%
y_pred=grid.predict(X_test)

# %%
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.071245      0.003405         0.007537        0.002354
# 1        0.453726      0.015096         0.014462        0.002773
# 2        0.443230      0.008233         0.015593        0.001746
# 3        0.056168      0.006367         0.004989        0.001531
# 4        0.434462      0.013577         0.020576        0.002002
# 5        0.432010      0.007765         0.014443        0.003060
# 6        0.129658      0.007885         0.003885        0.002205
# 7        1.226022      0.027544         0.017758        0.005898
# 8        1.537038      0.376854         0.022583        0.007530
# 9        0.146522      0.012339         0.003729        0.001972
# 10       2.372138      0.123277         0.036316        0.005481
# 11       2.574590      0.227732         0.035455        0.003255
# 12       0.132703      0.021725         0.011801        0.003371
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 24
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[48555.6005292]

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8616871063396023

# %%
import pickle

# %%
filename="final_model_RFR.sav"

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("final_model_RFR.sav",'rb'))

# %%
result=loaded_model.predict([[24,34,0,1,1]])

# %%
result
# Out:
# array([47662.5237879])
