# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children',  'sex_male','smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid={'n_estimators':[10,100,100],
            'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'max_features':['sqrt', 'log2']}

# %%
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
re
# Out:
# {'mean_fit_time': array([0.08167305, 0.48340402, 0.46337919, 0.04982972, 0.45023074,
#         0.4518692 , 0.17607675, 1.6475029 , 1.6894609 , 0.17324972,
#         1.68989758, 1.7151401 , 0.06043897, 0.44117074, 0.4587019 ,
#         0.05468335, 0.48157334, 0.48315516, 0.05934238, 0.54043579,
#         0.53848085, 0.06555858, 0.61127267, 0.51720991]),
#  'std_fit_time': array([0.01753886, 0.02084373, 0.02169972, 0.00011593, 0.0029793 ,
#         0.00327318, 0.00721134, 0.03653715, 0.04015702, 0.00941608,
#         0.0266644 , 0.04913806, 0.00608199, 0.00968646, 0.00823022,
#         0.0021429 , 0.01077773, 0.00927859, 0.00335535, 0.00872891,
#         0.00739928, 0.01015456, 0.04866422, 0.03166212]),
#  'mean_score_time': array([0.00889516, 0.0223999 , 0.01982579, 0.00686049, 0.0221303 ,
#         0.01892815, 0.00465102, 0.01677361, 0.01793971, 0.00712662,
#         0.01926584, 0.01849608, 0.00476723, 0.0189712 , 0.01970787,
#         0.00630913, 0.0208643 , 0.02201543, 0.00632763, 0.02060795,
#         0.01973219, 0.00899549, 0.02224655, 0.01482782]),
#  'std_score_time': array([0.00204618, 0.00399631, 0.00336693, 0.00309566, 0.0036523 ,
#         0.00168793, 0.00173627, 0.00197458, 0.00287229, 0.00116144,
#         0.00252349, 0.00218449, 0.00164662, 0.00207915, 0.00389356,
#         0.00160643, 0.00443831, 0.0020387 , 0.00240254, 0.00195051,
#         0.00105208, 0.00307778, 0.0029373 , 0.00506469]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                     'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=['sqrt', 'sqrt', 'sqrt', 'log2', 'log2', 'log2', 'sqrt',
#                     'sqrt', 'sqrt', 'log2', 'log2', 'log2', 'sqrt', 'sqrt',
#                     'sqrt', 'log2', 'log2', 'log2', 'sqrt', 'sqrt', 'sqrt',
#                     'log2', 'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[10, 100, 100, 10, 100, 100, 10, 100, 100, 10, 100, 100,
#                     10, 100, 100, 10, 100, 100, 10, 100, 100, 10, 100, 100],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'squared_error',
#    'max_features': 'sqrt',
#    'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}],
#  'split0_test_score': array([0.84876892, 0.85977848, 0.8575106 , 0.83977247, 0.86111046,
#         0.85389906, 0.82591532, 0.85818541, 0.85904102, 0.85169411,
#         0.85328138, 0.85884842, 0.84740709, 0.85759533, 0.85849597,
#         0.83917005, 0.8612132 , 0.85891017, 0.85540025, 0.8575768 ,
#         0.85814769, 0.84264512, 0.85683982, 0.85957838]),
#  'split1_test_score': array([0.77137445, 0.7864768 , 0.77902382, 0.75872421, 0.78103943,
#         0.78384366, 0.76765518, 0.78158205, 0.7791954 , 0.76009486,
#         0.78315866, 0.78076936, 0.76393162, 0.78107316, 0.78102655,
#         0.75258281, 0.77779574, 0.77774136, 0.76488903, 0.77812022,
#         0.78282971, 0.74402058, 0.78088697, 0.77966272]),
#  'split2_test_score': array([0.84992839, 0.86346119, 0.8615996 , 0.85434806, 0.8628996 ,
#         0.86055801, 0.83329158, 0.86187263, 0.85649262, 0.83802545,
#         0.86190244, 0.85963335, 0.85013405, 0.8592302 , 0.85938444,
#         0.83586983, 0.85978404, 0.86002836, 0.85436773, 0.85732709,
#         0.85768775, 0.84525261, 0.86267715, 0.86120114]),
#  'split3_test_score': array([0.80978944, 0.83087503, 0.83043552, 0.81145738, 0.83014493,
#         0.82833245, 0.8200345 , 0.82797776, 0.82362203, 0.810719  ,
#         0.83032995, 0.82482319, 0.82505594, 0.82889357, 0.82847839,
#         0.83193902, 0.82652478, 0.82836923, 0.8040877 , 0.82692717,
#         0.82989411, 0.82181829, 0.82920329, 0.82427254]),
#  'split4_test_score': array([0.83361648, 0.83752619, 0.84282023, 0.82151611, 0.83797531,
#         0.84170944, 0.83538851, 0.84133009, 0.84441138, 0.83984227,
#         0.84362783, 0.84538193, 0.8259932 , 0.83676916, 0.843811  ,
#         0.82632563, 0.83628365, 0.84188253, 0.82842166, 0.83845277,
#         0.83946654, 0.82951902, 0.8435672 , 0.8416128 ]),
#  'mean_test_score': array([0.82269554, 0.83562354, 0.83427795, 0.81716365, 0.83463395,
#         0.83366852, 0.81645702, 0.83418959, 0.83255249, 0.82007514,
#         0.83446005, 0.83389125, 0.82250438, 0.83271228, 0.83423927,
#         0.81717747, 0.83232028, 0.83338633, 0.82143327, 0.83168081,
#         0.83360516, 0.81665113, 0.83463489, 0.83326552]),
#  'std_test_score': array([0.0294657 , 0.02756797, 0.02975561, 0.03274298, 0.02967706,
#         0.02723221, 0.02500273, 0.02898026, 0.02946909, 0.03285691,
#         0.02771377, 0.02939971, 0.03109017, 0.02835492, 0.02890352,
#         0.03257957, 0.03036867, 0.03018272, 0.03401585, 0.02920797,
#         0.0275992 , 0.03731276, 0.02924912, 0.02998859]),
#  'rank_test_score': array([17,  1,  5, 22,  3,  9, 24,  7, 14, 20,  4,  8, 18, 13,  6, 21, 15,
#         11, 19, 16, 10, 23,  2, 12])}

# %%
print("The Best R_score Model Is{}:".format(grid.best_params_))
# Out:
# The Best R_score Model Is{'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.081673      0.017539         0.008895        0.002046
# 1        0.483404      0.020844         0.022400        0.003996
# 2        0.463379      0.021700         0.019826        0.003367
# 3        0.049830      0.000116         0.006860        0.003096
# 4        0.450231      0.002979         0.022130        0.003652
# 5        0.451869      0.003273         0.018928        0.001688
# 6        0.176077      0.007211         0.004651        0.001736
# 7        1.647503      0.036537         0.016774        0.001975
# 8        1.689461      0.040157         0.017940        0.002872
# 9        0.173250      0.009416         0.007127        0.001161
# 10       1.689898      0.026664         0.019266        0.002523
# 11       1.715140      0.049138         0.018496        0.002184
# 12       0.060439      0.006082         0.004767        0.001647
# 13       0.441171      0.009686         0.018971        0.002079
# 14       0.458702      0.008230         0.019708        0.003894
# 15       0.054683      0.002143         0.006309        0.001606
# 16       0.481573      0.010778         0.020864        0.004438
# 17       0.483155      0.009279         0.022015        0.002039
# 18       0.059342      0.003355         0.006328        0.002403
# 19       0.540436      0.008729         0.020608        0.001951
# 20       0.538481      0.007399         0.019732        0.001052
# 21       0.065559      0.010155         0.008995        0.003078
# 22       0.611273      0.048664         0.022247        0.002937
# 23       0.517210      0.031662         0.014828        0.005065
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               sqrt                100
# 3    squared_error               log2                 10
# 4    squared_error               log2                100
# 5    squared_error               log2                100
# 6   absolute_error               sqrt                 10
# 7   absolute_error               sqrt                100
# 8   absolute_error               sqrt                100
# 9   absolute_error               log2                 10
# 10  absolute_error               log2                100
# 11  absolute_error               log2                100
# 12    friedman_mse               sqrt                 10
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               sqrt                100
# 15    friedman_mse               log2                 10
# 16    friedman_mse               log2                100
# 17    friedman_mse               log2                100
# 18         poisson               sqrt                 10
# 19         poisson               sqrt                100
# 20         poisson               sqrt                100
# 21         poisson               log2                 10
# 22         poisson               log2                100
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.848769
# 1   {'criterion': 'squared_error', 'max_features':...           0.859778
# 2   {'criterion': 'squared_error', 'max_features':...           0.857511
# 3   {'criterion': 'squared_error', 'max_features':...           0.839772
# 4   {'criterion': 'squared_error', 'max_features':...           0.861110
# 5   {'criterion': 'squared_error', 'max_features':...           0.853899
# 6   {'criterion': 'absolute_error', 'max_features'...           0.825915
# 7   {'criterion': 'absolute_error', 'max_features'...           0.858185
# 8   {'criterion': 'absolute_error', 'max_features'...           0.859041
# 9   {'criterion': 'absolute_error', 'max_features'...           0.851694
# 10  {'criterion': 'absolute_error', 'max_features'...           0.853281
# 11  {'criterion': 'absolute_error', 'max_features'...           0.858848
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.847407
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.857595
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.858496
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.839170
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.861213
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.858910
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.855400
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857577
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858148
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.842645
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.856840
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.859578
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.771374           0.849928           0.809789
# 1            0.786477           0.863461           0.830875
# 2            0.779024           0.861600           0.830436
# 3            0.758724           0.854348           0.811457
# 4            0.781039           0.862900           0.830145
# 5            0.783844           0.860558           0.828332
# 6            0.767655           0.833292           0.820035
# 7            0.781582           0.861873           0.827978
# 8            0.779195           0.856493           0.823622
# 9            0.760095           0.838025           0.810719
# 10           0.783159           0.861902           0.830330
# 11           0.780769           0.859633           0.824823
# 12           0.763932           0.850134           0.825056
# 13           0.781073           0.859230           0.828894
# 14           0.781027           0.859384           0.828478
# 15           0.752583           0.835870           0.831939
# 16           0.777796           0.859784           0.826525
# 17           0.777741           0.860028           0.828369
# 18           0.764889           0.854368           0.804088
# 19           0.778120           0.857327           0.826927
# 20           0.782830           0.857688           0.829894
# 21           0.744021           0.845253           0.821818
# 22           0.780887           0.862677           0.829203
# 23           0.779663           0.861201           0.824273
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.833616         0.822696        0.029466               17
# 1            0.837526         0.835624        0.027568                1
# 2            0.842820         0.834278        0.029756                5
# 3            0.821516         0.817164        0.032743               22
# 4            0.837975         0.834634        0.029677                3
# 5            0.841709         0.833669        0.027232                9
# 6            0.835389         0.816457        0.025003               24
# 7            0.841330         0.834190        0.028980                7
# 8            0.844411         0.832552        0.029469               14
# 9            0.839842         0.820075        0.032857               20
# 10           0.843628         0.834460        0.027714                4
# 11           0.845382         0.833891        0.029400                8
# 12           0.825993         0.822504        0.031090               18
# 13           0.836769         0.832712        0.028355               13
# 14           0.843811         0.834239        0.028904                6
# 15           0.826326         0.817177        0.032580               21
# 16           0.836284         0.832320        0.030369               15
# 17           0.841883         0.833386        0.030183               11
# 18           0.828422         0.821433        0.034016               19
# 19           0.838453         0.831681        0.029208               16
# 20           0.839467         0.833605        0.027599               10
# 21           0.829519         0.816651        0.037313               23
# 22           0.843567         0.834635        0.029249                2
# 23           0.841613         0.833266        0.029989               12

# %%
 age_input=float(input("Age:"))
 bmi_input=float(input("BMI:"))
 children_input=float(input("Children:"))
 sex_male_input=int(input("Sex Male 0 or 1:"))
 smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 34
# BMI: 23
# Children: 12
# Sex Male 0 or 1: 34
# Smoker Yes 0 or 1: 23

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19569.7913468]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
